# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    'linearSVC-l1': {
        'Time': [155.9380832, 155.6315588, 155.0291419, 154.9044991, 154.8344287, 155.2675423],
        'Accuracy': [0.9915, 0.9915, 0.9914666667, 0.991425, 0.99142, 0.9914623333]
    },
    'linearSVC-l2': {
        'Time': [4.25821894, 4.367032912, 4.427871938, 4.339217808, 4.29545241, 4.337558801],
        'Accuracy': [0.9919, 0.9919, 0.9919, 0.9919, 0.9919, 0.9919]
    },
    'Logistic-l1': {
        'Time': [48.69599327, 48.15331275, 48.30453512, 47.96978597, 47.85323913, 48.19537325],
        'Accuracy': [0.9906, 0.99065, 0.9906333333, 0.99065, 0.99066, 0.9906386667]
    },
    'Logistic-l2': {
        'Time': [38.38444605, 37.62261497, 37.45782072, 37.61548388, 37.51529014, 37.71913115],
        'Accuracy': [0.9903, 0.9903, 0.9903, 0.9903, 0.9903, 0.9903]
    }
}

df_linearSVC_l1 = pd.DataFrame(data['linearSVC-l1'])
df_linearSVC_l2 = pd.DataFrame(data['linearSVC-l2'])

# Plotting
plt.figure(figsize=(10, 6))

plt.plot(df_linearSVC_l1.index[:-1], df_linearSVC_l1['Time'][:-1], marker='o', color = 'blue' , linestyle='-', label='LinearSVC-L1')
plt.plot(df_linearSVC_l2.index[:-1], df_linearSVC_l2['Time'][:-1], marker='o', color ='red', linestyle='-', label='LinearSVC-L2')
plt.hlines(df_linearSVC_l1['Time'].mean(), xmin=df_linearSVC_l1.index[0], xmax=df_linearSVC_l1.index[-1], color='black', linestyle='--', label='Average Time (LinearSVC-L1)')
plt.hlines(df_linearSVC_l2['Time'].mean(), xmin=df_linearSVC_l2.index[0], xmax=df_linearSVC_l2.index[-1], color = 'brown' , linestyle='--', label='Average Time (LinearSVC-L2)')

plt.text(df_linearSVC_l1.index[-1], df_linearSVC_l1['Time'].mean(), f'{df_linearSVC_l1["Time"].iloc[-1]:.4f}s', ha='right', va='bottom', color='blue')
plt.text(df_linearSVC_l2.index[-1], df_linearSVC_l2['Time'].mean(), f'{df_linearSVC_l2["Time"].iloc[-1]:.4f}s', ha='right', va='bottom', color='red')

plt.title('Training Time Comparison of LinearSVC with l1 and l2 penalty')
plt.xlabel('Iteration')
plt.ylabel('Time (seconds)')
plt.xticks(df_linearSVC_l1.index)
plt.legend()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    'linearSVC-l1': {
        'Time': [155.9380832, 155.6315588, 155.0291419, 154.9044991, 154.8344287, 155.2675423],
        'Accuracy': [0.9915, 0.9915, 0.9914666667, 0.991425, 0.99142, 0.9914623333]
    },
    'linearSVC-l2': {
        'Time': [4.25821894, 4.367032912, 4.427871938, 4.339217808, 4.29545241, 4.337558801],
        'Accuracy': [0.9919, 0.9919, 0.9919, 0.9919, 0.9919, 0.9919]
    },
    'Logistic-l1': {
        'Time': [48.69599327, 48.15331275, 48.30453512, 47.96978597, 47.85323913, 48.19537325],
        'Accuracy': [0.9906, 0.99065, 0.9906333333, 0.99065, 0.99066, 0.9906386667]
    },
    'Logistic-l2': {
        'Time': [38.38444605, 37.62261497, 37.45782072, 37.61548388, 37.51529014, 37.71913115],
        'Accuracy': [0.9903, 0.9903, 0.9903, 0.9903, 0.9903, 0.9903]
    }
}

df_linearSVC_l1 = pd.DataFrame(data['linearSVC-l1'])
df_linearSVC_l2 = pd.DataFrame(data['linearSVC-l2'])

# Plotting
plt.figure(figsize=(10, 6))
plt.ylim(0.99, 0.992)
plt.plot(df_linearSVC_l1.index[:-1], df_linearSVC_l1['Accuracy'][:-1], marker='o', color = 'blue' , linestyle='-', label='LinearSVC-L1')
plt.plot(df_linearSVC_l2.index[:-1], df_linearSVC_l2['Accuracy'][:-1], marker='o', color ='red', linestyle='-', label='LinearSVC-L2')
plt.hlines(df_linearSVC_l1['Accuracy'].mean(), xmin=df_linearSVC_l1.index[0], xmax=df_linearSVC_l1.index[-1], color='black', linestyle='--', label='Average Accuracy (LinearSVC-L1)')
plt.hlines(df_linearSVC_l2['Accuracy'].mean(), xmin=df_linearSVC_l2.index[0], xmax=df_linearSVC_l2.index[-1], color = 'brown' , linestyle='--', label='Average Accuracy (LinearSVC-L2)')

plt.text(df_linearSVC_l1.index[-1], df_linearSVC_l1['Accuracy'].mean(), f'{df_linearSVC_l1["Accuracy"].iloc[-1]:.4f}', ha='right', va='bottom', color='blue')
plt.text(df_linearSVC_l2.index[-1], df_linearSVC_l2['Accuracy'].mean(), f'{df_linearSVC_l2["Accuracy"].iloc[-1]:.4f}', ha='right', va='bottom', color='red')

plt.title('Accuracy Comparison for LinearSVC with l1 and l2 penalty')
plt.xlabel('Iteration')
plt.ylabel('Accuracy')
plt.xticks(df_linearSVC_l1.index)
plt.legend()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    'linearSVC-l1': {
        'Time': [155.9380832, 155.6315588, 155.0291419, 154.9044991, 154.8344287, 155.2675423],
        'Accuracy': [0.9915, 0.9915, 0.9914666667, 0.991425, 0.99142, 0.9914623333]
    },
    'linearSVC-l2': {
        'Time': [4.25821894, 4.367032912, 4.427871938, 4.339217808, 4.29545241, 4.337558801],
        'Accuracy': [0.9919, 0.9919, 0.9919, 0.9919, 0.9919, 0.9919]
    },
    'Logistic-l1': {
        'Time': [48.69599327, 48.15331275, 48.30453512, 47.96978597, 47.85323913, 48.19537325],
        'Accuracy': [0.9906, 0.99065, 0.9906333333, 0.99065, 0.99066, 0.9906386667]
    },
    'Logistic-l2': {
        'Time': [38.38444605, 37.62261497, 37.45782072, 37.61548388, 37.51529014, 37.71913115],
        'Accuracy': [0.9903, 0.9903, 0.9903, 0.9903, 0.9903, 0.9903]
    }
}

df_logistic_l1 = pd.DataFrame(data['Logistic-l1'])
df_logistic_l2 = pd.DataFrame(data['Logistic-l2'])

# Plotting
plt.figure(figsize=(10, 6))
plt.ylim(20, 55)
plt.plot(df_logistic_l1.index[:-1], df_logistic_l1['Time'][:-1], marker='o', color='blue', linestyle='-', label='Logistic-l1')
plt.plot(df_logistic_l2.index[:-1], df_logistic_l2['Time'][:-1], marker='o', color='red', linestyle='-', label='Logistic-l2')
plt.hlines(df_logistic_l1['Time'].mean(), xmin=df_logistic_l1.index[0], xmax=df_logistic_l1.index[-1], color='black', linestyle='--', label='Average Time (Logistic-l1)')
plt.hlines(df_logistic_l2['Time'].mean(), xmin=df_logistic_l2.index[0], xmax=df_logistic_l2.index[-1], color='brown', linestyle='--', label='Average Time (Logistic-l2)')

plt.text(df_logistic_l1.index[-1], df_logistic_l1['Time'].mean(), f'{df_logistic_l1["Time"].iloc[-1]:.4f}s', ha='right', va='bottom', color='blue')
plt.text(df_logistic_l2.index[-1], df_logistic_l2['Time'].mean(), f'{df_logistic_l2["Time"].iloc[-1]:.4f}s', ha='right', va='bottom', color='red')

plt.title('Training Time Comparison of LogisticRegression with L1 and L2 penalty')
plt.xlabel('Iteration')
plt.ylabel('Time (seconds)')
plt.xticks(df_logistic_l1.index)
plt.legend()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    'Logistic-l1': {
        'Time': [48.69599327, 48.15331275, 48.30453512, 47.96978597, 47.85323913, 48.19537325],
        'Accuracy': [0.9906, 0.99065, 0.9906333333, 0.99065, 0.99066, 0.9906386667]
    },
    'Logistic-l2': {
        'Time': [38.38444605, 37.62261497, 37.45782072, 37.61548388, 37.51529014, 37.71913115],
        'Accuracy': [0.9903, 0.9903, 0.9903, 0.9903, 0.9903, 0.9903]
    }
}

df_logistic_l1 = pd.DataFrame(data['Logistic-l1'])
df_logistic_l2 = pd.DataFrame(data['Logistic-l2'])

# Plotting
plt.figure(figsize=(10, 6))
plt.ylim(0.99, 0.991)

plt.plot(df_logistic_l1.index, df_logistic_l1['Accuracy'], marker='o', color='blue', linestyle='-', label='Logistic-L1')
plt.plot(df_logistic_l2.index, df_logistic_l2['Accuracy'], marker='o', color='red', linestyle='-', label='Logistic-L2')
plt.hlines(df_logistic_l1['Accuracy'].mean(), xmin=df_logistic_l1.index[0], xmax=df_logistic_l1.index[-1], color='black', linestyle='--', label='Average Accuracy (Logistic-L1)')
plt.hlines(df_logistic_l2['Accuracy'].mean(), xmin=df_logistic_l2.index[0], xmax=df_logistic_l2.index[-1], color='brown', linestyle='--', label='Average Accuracy (Logistic-L2)')

plt.title('Accuracy Comparison for LogisticRegression with L1 and L2 penalty')
plt.xlabel('Iteration')
plt.ylabel('Accuracy')
plt.xticks(df_logistic_l1.index)
plt.legend()

# Add text annotations
plt.text(df_logistic_l1.index[-1], df_logistic_l1['Accuracy'].iloc[-1], f'{df_logistic_l1["Accuracy"].iloc[-1]:.4f}', ha='right', va='bottom', color='blue')
plt.text(df_logistic_l2.index[-1], df_logistic_l2['Accuracy'].iloc[-1], f'{df_logistic_l2["Accuracy"].iloc[-1]:.4f}', ha='right', va='bottom', color='red')

plt.show()
